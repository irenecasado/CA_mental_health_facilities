# %%
import os
from pathlib import Path

import pandas as pd
import pandas_bokeh
import altair as alt
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.0f}'.format

# %%
DATA_DIR = os.environ['DATA_DIR']

# %%
fips = pd.read_csv(DATA_DIR + "/raw/state_and_county_fips_master.csv")

# %%
ca_fips = fips[fips.state == "CA"]

# %%
#ca_fips["fip_clean"] = ca_fips.fips.replace(0, '')
ca_fips["county"] = ca_fips["fips"].astype(str).str[-3:]
# Out:
# /var/folders/5t/ptdbrrps2zzc0q0jvwkbsh980000gn/T/ipykernel_11300/4133493897.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_fips["county"] = ca_fips["fips"].astype(str).str[-3:]

# %%
ca_fips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 192 to 249
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fips    58 non-null     int64
#  1   name    58 non-null     object
#  2   state   58 non-null     object
#  3   county  58 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ KB

# %%
ca_fips
# Out:
#      fips                    name state county
# 192  6001          Alameda County    CA    001
# 193  6003           Alpine County    CA    003
# 194  6005           Amador County    CA    005
# 195  6007            Butte County    CA    007
# 196  6009        Calaveras County    CA    009
# 197  6011           Colusa County    CA    011
# 198  6013     Contra Costa County    CA    013
# 199  6015        Del Norte County    CA    015
# 200  6017        El Dorado County    CA    017
# 201  6019           Fresno County    CA    019
# 202  6021            Glenn County    CA    021
# 203  6023         Humboldt County    CA    023
# 204  6025         Imperial County    CA    025
# 205  6027             Inyo County    CA    027
# 206  6029             Kern County    CA    029
# 207  6031            Kings County    CA    031
# 208  6033             Lake County    CA    033
# 209  6035           Lassen County    CA    035
# 210  6037      Los Angeles County    CA    037
# ...

# %%
ca_fips['county'] = ca_fips['county'].astype(str)
# Out:
# /var/folders/5t/ptdbrrps2zzc0q0jvwkbsh980000gn/T/ipykernel_11300/2000170698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_fips['county'] = ca_fips['county'].astype(str)

# %%
ca_fips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 192 to 249
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fips    58 non-null     int64
#  1   name    58 non-null     object
#  2   state   58 non-null     object
#  3   county  58 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ KB

# %%
ca_fips.to_csv('ca_fips.csv')
