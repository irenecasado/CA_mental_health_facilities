# %%
import pandas as pd
import numpy as np
import datetime
import altair as alt
import os

# %%
data_dir = os.environ["DATA_DIR"]
raw_data = data_dir + "/raw/"
health_file = os.path.join(raw_data, 'healthcare_facility_locations.csv')
health_raw = pd.read_csv(health_file)

# %%
health_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14361 entries, 0 to 14360
# Data columns (total 59 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LICENSED_CERTIFIED              14361 non-null  object
#  1   FLAG                            733 non-null    object
#  2   T18_19                          2250 non-null   object
#  3   FACID                           14361 non-null  int64
#  4   FAC_STATUS_TYPE_CODE            14361 non-null  object
#  5   ASPEN_FACID                     14152 non-null  object
#  6   CCN                             9692 non-null   object
#  7   TERMINAT_SW                     251 non-null    object
#  8   PARTICIPATION_DATE              9625 non-null   object
#  9   APPROVAL_DATE                   9149 non-null   object
#  10  NPI                             8322 non-null   object
#  11  CAN_BE_DEEMED_FAC_TYPE          12502 non-null  object
#  12  CAN_BE_CERTIFIED_FAC_TYPE       12502 non-null  object
#  13  DEEMED                          10189 non-null  float64
#  14  AO_CD                           4479 non-null   float64
#  15  DMG_EFCTV_DT                    4478 non-null   object
#  16  AO_TRMNTN_DT                    357 non-null    object
#  17  AO_NAME                         4479 non-null   object
#  18  FACNAME                         14361 non-null  object
#  19  FAC_TYPE_CODE                   14361 non-null  object
#  20  FAC_FDR                         14361 non-null  object
#  21  LTC                             14361 non-null  object
#  22  CAPACITY                        14361 non-null  int64
#  23  ADDRESS                         14361 non-null  object
#  24  CITY                            14361 non-null  object
#  25  ZIP                             14361 non-null  int64
#  26  ZIP9                            11930 non-null  object
#  27  FACADMIN                        12237 non-null  object
#  28  CONTACT_EMAIL                   11924 non-null  object
#  29  CONTACT_FAX                     11792 non-null  object
#  30  CONTACT_PHONE_NUMBER            13343 non-null  object
#  31  COUNTY_CODE                     14361 non-null  int64
#  32  COUNTY_NAME                     14361 non-null  object
#  33  DISTRICT_NUMBER                 14361 non-null  int64
#  34  DISTRICT_NAME                   14361 non-null  object
#  35  ISFACMAIN                       14361 non-null  object
#  36  PARENT_FACID                    1660 non-null   float64
#  37  FAC_FAC_RELATIONSHIP_TYPE_CODE  14361 non-null  object
#  38  START_DATE                      1656 non-null   object
#  39  LICENSE_NUMBER                  13116 non-null  float64
#  40  BUSINESS_NAME                   12934 non-null  object
#  41  LICENSE_STATUS_DESCRIPTION      13116 non-null  object
#  42  INITIAL_LICENSE_DATE            12378 non-null  object
#  43  LICENSE_EFFECTIVE_DATE          13115 non-null  object
#  44  LICENSE_EXPIRATION_DATE         13115 non-null  object
#  45  ENTITY_TYPE_DESCRIPTION         13019 non-null  object
#  46  LATITUDE                        14361 non-null  float64
#  47  LONGITUDE                       14361 non-null  float64
#  48  LOCATION                        14361 non-null  object
#  49  OSHPD_ID                        8494 non-null   float64
#  50  CCLHO_CODE                      14361 non-null  int64
#  51  CCLHO_NAME                      14361 non-null  object
#  52  FIPS_COUNTY_CODE                14361 non-null  int64
#  53  BIRTHING_FACILITY_FLAG          252 non-null    object
#  54  TRAUMA_PED_CTR                  18 non-null     object
#  55  TRAUMA_CTR                      77 non-null     object
#  56  TYPE_OF_CARE                    238 non-null    object
#  57  CRITICAL_ACCESS_HOSPITAL        41 non-null     object
#  58  DATA_DATE                       14361 non-null  object
# dtypes: float64(7), int64(7), object(45)
# memory usage: 6.5+ MB

# %%
health_raw.FAC_STATUS_TYPE_CODE.unique()
# Out:
# array(['OPEN', 'CERTIFIED ONLY'], dtype=object)

# %% [markdown]
# Here, we are going to filter our data by 'FAC_STATUS_TYPE_CODE', as we only need the OPEN ones.

# %%
health_open = health_raw[health_raw['FAC_STATUS_TYPE_CODE'] == 'OPEN']

# %%
health_open.reset_index()
# Out:
#        index      LICENSED_CERTIFIED FLAG         T18_19      FACID  \
# 0          0  LICENSED AND CERTIFIED  NaN  T18 OR T18/19   10000001
# 1          1  LICENSED AND CERTIFIED  NaN  T18 OR T18/19   10000003
# 2          2  LICENSED AND CERTIFIED  NaN  T18 OR T18/19   10000004
# 3          3  LICENSED AND CERTIFIED  NaN  T18 OR T18/19   10000005
# 4          4  LICENSED AND CERTIFIED  NaN  T18 OR T18/19   10000024
# ...      ...                     ...  ...            ...        ...
# 12788  14356  LICENSED AND CERTIFIED  NaN            NaN  980002541
# 12789  14357  LICENSED AND CERTIFIED  NaN            NaN  980002546
# 12790  14358  LICENSED AND CERTIFIED  NaN            NaN  980002547
# 12791  14359  LICENSED AND CERTIFIED  NaN            NaN  980002548
# 12792  14360  LICENSED AND CERTIFIED  NaN            NaN  980002551
#
#       FAC_STATUS_TYPE_CODE  ASPEN_FACID     CCN TERMINAT_SW  \
# 0                     OPEN  CA010000001  555120         NaN
# 1                     OPEN  CA010000003  056090         NaN
# 2                     OPEN  CA010000004  056296         NaN
# 3                     OPEN  CA010000005  555703         NaN
# 4                     OPEN  CA010000024  056300         NaN
# ...                    ...          ...     ...         ...
# 12788                 OPEN  CA980002541  551653         NaN
# 12789                 OPEN   HH98002546  053164         NaN
# 12790                 OPEN  HH980002547  058309         NaN
# 12791                 OPEN  HH980002548  058468         NaN
# 12792                 OPEN   HH98002551  059678         NaN
#
#       PARTICIPATION_DATE  ... BIRTHING_FACILITY_FLAG TRAUMA_PED_CTR  \
# 0               7-Nov-80  ...                    NaN            NaN
# 1               1-Feb-74  ...                    NaN            NaN
# 2              14-Sep-71  ...                    NaN            NaN
# 3              18-Apr-97  ...                    NaN            NaN
# 4              10-Jul-73  ...                    NaN            NaN
# ...                  ...  ...                    ...            ...
# 12788           7-Jun-12  ...                    NaN            NaN
# 12789           6-Mar-18  ...                    NaN            NaN
# 12790           4-Aug-05  ...                    NaN            NaN
# 12791           9-Jun-08  ...                    NaN            NaN
# 12792          17-Aug-15  ...                    NaN            NaN
#
#       TRAUMA_CTR TYPE_OF_CARE  CRITICAL_ACCESS_HOSPITAL  DATA_DATE  \
# 0            NaN          NaN                       NaN  15-Mar-22
# 1            NaN          NaN                       NaN  15-Mar-22
# 2            NaN          NaN                       NaN  15-Mar-22
# 3            NaN          NaN                       NaN  15-Mar-22
# 4            NaN          NaN                       NaN  15-Mar-22
# ...          ...          ...                       ...        ...
# 12788        NaN          NaN                       NaN  15-Mar-22
# 12789        NaN          NaN                       NaN  15-Mar-22
# 12790        NaN          NaN                       NaN  15-Mar-22
# 12791        NaN          NaN                       NaN  15-Mar-22
# 12792        NaN          NaN                       NaN  15-Mar-22
#
#       primary_care nursing pediatric mental_health
# 0            False    True     False         False
# 1            False    True     False         False
# 2            False    True     False         False
# 3            False    True     False         False
# 4            False    True     False         False
# ...            ...     ...       ...           ...
# 12788        False   False     False         False
# 12789        False   False     False         False
# 12790        False   False     False         False
# 12791        False   False     False         False
# 12792        False   False     False         False
#
# [12793 rows x 64 columns]

# %%
health_open.FAC_FDR.unique()
# Out:
# array(['SKILLED NURSING FACILITY',
#        'INTERMEDIATE CARE FACILITY-DD/H/N/CN/IID', 'HOME HEALTH AGENCY',
#        'CONGREGATE LIVING HEALTH FACILITY', 'HOSPICE FACILITY',
#        'GENERAL ACUTE CARE HOSPITAL', 'PRIMARY CARE CLINIC',
#        'ACUTE PSYCHIATRIC HOSPITAL', 'ALTERNATIVE BIRTHING CENTER',
#        'PSYCHOLOGY CLINIC', 'OTHER', 'HOSPICE', 'SURGICAL CLINIC',
#        'REHABILITATION CLINIC', 'ADULT DAY HEALTH CARE',
#        'INTERMEDIATE CARE FACILITY',
#        'PEDIATRIC DAY HEALTH & RESPITE CARE FACILITY',
#        'CHRONIC DIALYSIS CLINIC', 'CHEMICAL DEPENDENCY RECOVERY HOSPITAL',
#        'CORRECTIONAL TREATMENT CENTER', 'REFERRAL AGENCY'], dtype=object)

# %% [markdown]
# Here, we create a new column per main category: primary_care, nursing, pediatric, mental_health. **We can modify it as we want.**
#
# - primary_care = PRIMARY CARE CLINIC + GENERAL ACUTE CARE HOSPITAL
# - nursing = SKILLED NURSING FACILITY + ADULT DAY HEALTH CARE
# - pediatric = PEDIATRIC DAY HEALTH & RESPITE CARE FACILITY + ALTERNATIVE BIRTHING CENTER
# - mental_health = ACUTE PSYCHIATRIC HOSPITAL + PSYCHOLOGY CLINIC + REHABILITATION CLINIC

# %%
health_open['primary_care'] = health_open.FAC_FDR.str.contains('PRIMARY CARE CLINIC|GENERAL ACUTE CARE HOSPITAL', regex=True)
# Out:
# /var/folders/5t/ptdbrrps2zzc0q0jvwkbsh980000gn/T/ipykernel_93862/1430501906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_open['primary_care'] = health_open.FAC_FDR.str.contains('PRIMARY CARE CLINIC|GENERAL ACUTE CARE HOSPITAL', regex=True)

# %%
health_open['nursing'] = health_open.FAC_FDR.str.contains('SKILLED NURSING FACILITY|ADULT DAY HEALTH CARE', regex=True)
# Out:
# /var/folders/5t/ptdbrrps2zzc0q0jvwkbsh980000gn/T/ipykernel_93862/1610038100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_open['nursing'] = health_open.FAC_FDR.str.contains('SKILLED NURSING FACILITY|ADULT DAY HEALTH CARE', regex=True)

# %%
health_open['pediatric'] = health_open.FAC_FDR.str.contains('PEDIATRIC DAY HEALTH & RESPITE CARE FACILITY|ALTERNATIVE BIRTHING CENTER', regex=True)
# Out:
# /var/folders/5t/ptdbrrps2zzc0q0jvwkbsh980000gn/T/ipykernel_93862/3336603724.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_open['pediatric'] = health_open.FAC_FDR.str.contains('PEDIATRIC DAY HEALTH & RESPITE CARE FACILITY|ALTERNATIVE BIRTHING CENTER', regex=True)

# %%
health_open['mental_health'] = health_open.FAC_FDR.str.contains('ACUTE PSYCHIATRIC HOSPITAL|PSYCHOLOGY CLINIC|REHABILITATION CLINIC', regex=True)
# Out:
# /var/folders/5t/ptdbrrps2zzc0q0jvwkbsh980000gn/T/ipykernel_93862/3523920154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_open['mental_health'] = health_open.FAC_FDR.str.contains('ACUTE PSYCHIATRIC HOSPITAL|PSYCHOLOGY CLINIC|REHABILITATION CLINIC', regex=True)

# %%
health_open.LICENSE_STATUS_DESCRIPTION.unique()
# Out:
# array(['ACTIVE', nan, 'INACTIVE - CAPEN DECISION'], dtype=object)

# %% [markdown]
# Here, we are filtering again, this time by 'LICENSE_STATUS_DESCRIPTION', as we only need the ACTIVE.

# %%
health_open_active = health_open[health_open.LICENSE_STATUS_DESCRIPTION == 'ACTIVE']

# %%
health_open_active.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12560 entries, 0 to 14360
# Data columns (total 63 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LICENSED_CERTIFIED              12560 non-null  object
#  1   FLAG                            706 non-null    object
#  2   T18_19                          2249 non-null   object
#  3   FACID                           12560 non-null  int64
#  4   FAC_STATUS_TYPE_CODE            12560 non-null  object
#  5   ASPEN_FACID                     12379 non-null  object
#  6   CCN                             8311 non-null   object
#  7   TERMINAT_SW                     140 non-null    object
#  8   PARTICIPATION_DATE              8254 non-null   object
#  9   APPROVAL_DATE                   7840 non-null   object
#  10  NPI                             7209 non-null   object
#  11  CAN_BE_DEEMED_FAC_TYPE          10972 non-null  object
#  12  CAN_BE_CERTIFIED_FAC_TYPE       10972 non-null  object
#  13  DEEMED                          8707 non-null   float64
#  14  AO_CD                           3915 non-null   float64
#  15  DMG_EFCTV_DT                    3915 non-null   object
#  16  AO_TRMNTN_DT                    286 non-null    object
#  17  AO_NAME                         3915 non-null   object
#  18  FACNAME                         12560 non-null  object
#  19  FAC_TYPE_CODE                   12560 non-null  object
#  20  FAC_FDR                         12560 non-null  object
#  21  LTC                             12560 non-null  object
#  22  CAPACITY                        12560 non-null  int64
#  23  ADDRESS                         12560 non-null  object
#  24  CITY                            12560 non-null  object
#  25  ZIP                             12560 non-null  int64
#  26  ZIP9                            10476 non-null  object
#  27  FACADMIN                        11246 non-null  object
#  28  CONTACT_EMAIL                   11368 non-null  object
#  29  CONTACT_FAX                     11041 non-null  object
#  30  CONTACT_PHONE_NUMBER            11855 non-null  object
#  31  COUNTY_CODE                     12560 non-null  int64
#  32  COUNTY_NAME                     12560 non-null  object
#  33  DISTRICT_NUMBER                 12560 non-null  int64
#  34  DISTRICT_NAME                   12560 non-null  object
#  35  ISFACMAIN                       12560 non-null  object
#  36  PARENT_FACID                    1453 non-null   float64
#  37  FAC_FAC_RELATIONSHIP_TYPE_CODE  12560 non-null  object
#  38  START_DATE                      1449 non-null   object
#  39  LICENSE_NUMBER                  12560 non-null  float64
#  40  BUSINESS_NAME                   12482 non-null  object
#  41  LICENSE_STATUS_DESCRIPTION      12560 non-null  object
#  42  INITIAL_LICENSE_DATE            11892 non-null  object
#  43  LICENSE_EFFECTIVE_DATE          12559 non-null  object
#  44  LICENSE_EXPIRATION_DATE         12559 non-null  object
#  45  ENTITY_TYPE_DESCRIPTION         12557 non-null  object
#  46  LATITUDE                        12560 non-null  float64
#  47  LONGITUDE                       12560 non-null  float64
#  48  LOCATION                        12560 non-null  object
#  49  OSHPD_ID                        8126 non-null   float64
#  50  CCLHO_CODE                      12560 non-null  int64
#  51  CCLHO_NAME                      12560 non-null  object
#  52  FIPS_COUNTY_CODE                12560 non-null  int64
#  53  BIRTHING_FACILITY_FLAG          252 non-null    object
#  54  TRAUMA_PED_CTR                  18 non-null     object
#  55  TRAUMA_CTR                      77 non-null     object
#  56  TYPE_OF_CARE                    238 non-null    object
#  57  CRITICAL_ACCESS_HOSPITAL        40 non-null     object
#  58  DATA_DATE                       12560 non-null  object
#  59  primary_care                    12560 non-null  bool
#  60  nursing                         12560 non-null  bool
#  61  pediatric                       12560 non-null  bool
#  62  mental_health                   12560 non-null  bool
# dtypes: bool(4), float64(7), int64(7), object(45)
# memory usage: 5.8+ MB

# %%
health_open_active
# Out:
#            LICENSED_CERTIFIED FLAG         T18_19      FACID  \
# 0      LICENSED AND CERTIFIED  NaN  T18 OR T18/19   10000001
# 1      LICENSED AND CERTIFIED  NaN  T18 OR T18/19   10000003
# 2      LICENSED AND CERTIFIED  NaN  T18 OR T18/19   10000004
# 3      LICENSED AND CERTIFIED  NaN  T18 OR T18/19   10000005
# 4      LICENSED AND CERTIFIED  NaN  T18 OR T18/19   10000024
# ...                       ...  ...            ...        ...
# 14356  LICENSED AND CERTIFIED  NaN            NaN  980002541
# 14357  LICENSED AND CERTIFIED  NaN            NaN  980002546
# 14358  LICENSED AND CERTIFIED  NaN            NaN  980002547
# 14359  LICENSED AND CERTIFIED  NaN            NaN  980002548
# 14360  LICENSED AND CERTIFIED  NaN            NaN  980002551
#
#       FAC_STATUS_TYPE_CODE  ASPEN_FACID     CCN TERMINAT_SW  \
# 0                     OPEN  CA010000001  555120         NaN
# 1                     OPEN  CA010000003  056090         NaN
# 2                     OPEN  CA010000004  056296         NaN
# 3                     OPEN  CA010000005  555703         NaN
# 4                     OPEN  CA010000024  056300         NaN
# ...                    ...          ...     ...         ...
# 14356                 OPEN  CA980002541  551653         NaN
# 14357                 OPEN   HH98002546  053164         NaN
# 14358                 OPEN  HH980002547  058309         NaN
# 14359                 OPEN  HH980002548  058468         NaN
# 14360                 OPEN   HH98002551  059678         NaN
#
#       PARTICIPATION_DATE APPROVAL_DATE  ... BIRTHING_FACILITY_FLAG  \
# 0               7-Nov-80     13-Jul-21  ...                    NaN
# 1               1-Feb-74           NaN  ...                    NaN
# 2              14-Sep-71     26-Dec-19  ...                    NaN
# 3              18-Apr-97     13-Aug-19  ...                    NaN
# 4              10-Jul-73     13-Aug-21  ...                    NaN
# ...                  ...           ...  ...                    ...
# 14356           7-Jun-12     14-Oct-21  ...                    NaN
# 14357           6-Mar-18     23-Aug-18  ...                    NaN
# 14358           4-Aug-05     24-Apr-20  ...                    NaN
# 14359           9-Jun-08     27-Nov-18  ...                    NaN
# 14360          17-Aug-15     29-Dec-17  ...                    NaN
#
#       TRAUMA_PED_CTR TRAUMA_CTR  TYPE_OF_CARE  CRITICAL_ACCESS_HOSPITAL  \
# 0                NaN        NaN           NaN                       NaN
# 1                NaN        NaN           NaN                       NaN
# 2                NaN        NaN           NaN                       NaN
# 3                NaN        NaN           NaN                       NaN
# 4                NaN        NaN           NaN                       NaN
# ...              ...        ...           ...                       ...
# 14356            NaN        NaN           NaN                       NaN
# 14357            NaN        NaN           NaN                       NaN
# 14358            NaN        NaN           NaN                       NaN
# 14359            NaN        NaN           NaN                       NaN
# 14360            NaN        NaN           NaN                       NaN
#
#        DATA_DATE primary_care nursing pediatric mental_health
# 0      15-Mar-22        False    True     False         False
# 1      15-Mar-22        False    True     False         False
# 2      15-Mar-22        False    True     False         False
# 3      15-Mar-22        False    True     False         False
# 4      15-Mar-22        False    True     False         False
# ...          ...          ...     ...       ...           ...
# 14356  15-Mar-22        False   False     False         False
# 14357  15-Mar-22        False   False     False         False
# 14358  15-Mar-22        False   False     False         False
# 14359  15-Mar-22        False   False     False         False
# 14360  15-Mar-22        False   False     False         False
#
# [12560 rows x 63 columns]
